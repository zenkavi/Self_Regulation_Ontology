# %% [markdown]
# Initial exploratory analyses of demographic data

# %%
import os,sys
import pandas,numpy
import seaborn as sns
import matplotlib.pyplot as plt

# this is kludgey but it works
sys.path.append('../utils')

from metadata_utils import load_metadata
from utils import get_info,get_behav_data

# %matplotlib inline

# %load_ext rpy2.ipython
from IPython.display import display, HTML
pandas.set_option('max_colwidth', 100)


basedir=get_info('base_directory')
dataset=get_info('dataset')
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
demog=get_behav_data(dataset,'demographics.csv',full_dataset=True)
#pandas.read_csv(os.path.join(derived_dir,'surveydata/demographics.tsv'),delimiter='\t',index_col=0)
demog_metadata=load_metadata('demographics')
del demog['RelationshipStatus']
del demog['RentOwn']
badweight=demog['WeightPounds']<80
print('excluding %d subjects for weight < 80'%numpy.sum(badweight))
demog['WeightPounds'].loc[badweight]=numpy.nan
badheight=demog['HeightInches']<36
print('excluding %d subjects for height < 36'%numpy.sum(badheight))
demog['HeightInches'].loc[badheight]=numpy.nan

demog=demog.assign(BMI=demog['WeightPounds']*0.45 / (demog['HeightInches']*0.025)**2)
#demog['BMI']=demog['WeightPounds']*0.45 / (demog['HeightInches']*0.025)**2
demog.describe().T
# Out:
# Getting datasets...:
#  /Users/poldrack/code/Self_Regulation_Ontology/Data/Discovery_12-05-2016
#  /Users/poldrack/code/Self_Regulation_Ontology/Data/Validation_12-05-2016
# excluding 1 subjects for weight < 80
# excluding 3 subjects for height < 36
# /Users/poldrack/anaconda/envs/py34/lib/python3.4/site-packages/pandas/core/indexing.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#                              count          mean           std        min  \
# Age                          522.0     33.630268      7.877863  20.000000
# ArrestedChargedLifeCount     521.0      0.399232      0.945597   0.000000
# CaffienatedSodaCansPerDay    521.0      0.861804      1.335931  -1.000000
# CaffieneOtherSourcesDayMG    521.0     53.543186    226.832187 -12.000000
# CarDebt                      497.0      1.728370      1.338278   1.000000
# ChildrenNumber               522.0      0.781609      1.226001   0.000000
# CoffeeCupsPerDay             521.0      1.328215      1.746907   0.000000
# CreditCardDebt               498.0      1.819277      1.146892   1.000000
# DivorceCount                 522.0      0.155172      0.430219   0.000000
# EducationDebt                496.0      2.447581      1.848088   1.000000
# GamblingProblem              521.0      0.061420      0.297537   0.000000
# HeightInches                 519.0     67.566474      4.337467  50.000000
# HighestEducation             522.0      3.375479      0.898288   1.000000
# HispanicLatino               522.0      0.070881      0.256873   0.000000
# HouseholdIncome              522.0  48084.193487  31252.529223   0.000000
# LongestRelationship          522.0     85.191571     87.199980   0.000000
# MortgageDebt                 477.0      2.329140      2.276720   1.000000
# OtherDebtAmount              231.0      1.597403      1.301435   1.000000
# RelationshipNumber           522.0      3.333333      1.600144   0.000000
# RetirementAccount            522.0      0.270115      0.444445   0.000000
# RetirementPercentStocks      167.0     76.101796    540.127179   0.000000
# Sex                          522.0      0.501916      0.500476   0.000000
# TeaCupsPerDay                521.0      0.654511      1.291847   0.000000
# TrafficAccidentsLifeCount    521.0      1.180422      1.274785   0.000000
# TrafficTicketsLastYearCount  521.0      0.097889      0.361641   0.000000
# WeightPounds                 521.0    179.907869     50.373596  86.000000
# BMI                          518.0     28.263049      7.115846  17.338776
#
#                                      25%          50%           75%  \
# Age                             27.00000     32.00000     39.000000
# ArrestedChargedLifeCount         0.00000      0.00000      0.000000
# CaffienatedSodaCansPerDay        0.00000      0.00000      1.000000
# CaffieneOtherSourcesDayMG        0.00000      0.00000      0.000000
# CarDebt                          1.00000      1.00000      2.000000
# ChildrenNumber                   0.00000      0.00000      1.000000
# CoffeeCupsPerDay                 0.00000      1.00000      2.000000
# CreditCardDebt                   1.00000      1.00000      2.000000
# DivorceCount                     0.00000      0.00000      0.000000
# EducationDebt                    1.00000      1.00000      4.000000
# GamblingProblem                  0.00000      0.00000      0.000000
# HeightInches                    65.00000     68.00000     70.000000
# HighestEducation                 3.00000      3.00000      4.000000
# HispanicLatino                   0.00000      0.00000      0.000000
# HouseholdIncome              25000.00000  41500.00000  65000.000000
# LongestRelationship             24.00000     60.00000    120.000000
# MortgageDebt                     1.00000      1.00000      3.000000
# OtherDebtAmount                  1.00000      1.00000      1.000000
# RelationshipNumber               2.00000      3.00000      5.000000
# RetirementAccount                0.00000      0.00000      1.000000
# RetirementPercentStocks          0.00000     25.00000     65.500000
# Sex                              0.00000      1.00000      1.000000
# TeaCupsPerDay                    0.00000      0.00000      1.000000
# TrafficAccidentsLifeCount        0.00000      1.00000      2.000000
# TrafficTicketsLastYearCount      0.00000      0.00000      0.000000
# WeightPounds                   145.00000    170.00000    200.000000
# BMI                             23.25685     26.44898     31.640625
#
#                                        max
# Age                              59.000000
# ArrestedChargedLifeCount          6.000000
# CaffienatedSodaCansPerDay         6.000000
# CaffieneOtherSourcesDayMG      4000.000000
# CarDebt                           8.000000
# ChildrenNumber                    6.000000
# CoffeeCupsPerDay                 16.000000
# CreditCardDebt                    8.000000
# DivorceCount                      3.000000
# EducationDebt                     8.000000
# GamblingProblem                   2.000000
# HeightInches                     79.000000
# HighestEducation                  6.000000
# HispanicLatino                    1.000000
# HouseholdIncome              240000.000000
# LongestRelationship            1040.000000
# MortgageDebt                      8.000000
# OtherDebtAmount                   8.000000
# RelationshipNumber                6.000000
# RetirementAccount                 1.000000
# RetirementPercentStocks        7000.000000
# Sex                               1.000000
# TeaCupsPerDay                    12.000000
# TrafficAccidentsLifeCount         5.000000
# TrafficTicketsLastYearCount       3.000000
# WeightPounds                    373.000000
# BMI                              59.133728

# %%
print('Percentage with children: %0.1f'%(numpy.mean(demog.ChildrenNumber>1)*100))
print('Percentage ever divorced: %0.1f'%(numpy.mean(demog.DivorceCount>0)*100))
print('Percentage with current gambling problem: %0.1f'%(numpy.mean(demog.GamblingProblem>1)*100))
print('Percentage with at least one traffic ticket in last year: %0.1f'%(numpy.mean(demog.TrafficTicketsLastYearCount>0)*100))
print('Percentage arrested at least once: %0.1f'%(numpy.mean(demog.ArrestedChargedLifeCount>0)*100))
print('Percentage arrested more than once: %0.1f'%(numpy.mean(demog.ArrestedChargedLifeCount>1)*100))
print('Percentage with >$10,000 credit card debt: %0.1f'%(numpy.mean(demog.CreditCardDebt>3)*100))
# Out:
# Percentage with children: 24.5
# Percentage ever divorced: 13.0
# Percentage with current gambling problem: 1.5
# Percentage with at least one traffic ticket in last year: 8.0
# Percentage arrested at least once: 21.5
# Percentage arrested more than once: 10.3
# Percentage with >$10,000 credit card debt: 7.9

# %%
demog.BMI.hist(bins=50)
plt.title('BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency')
print('%0.2f percent subjects with BMI>30 (obese)'%(numpy.mean(demog.BMI>30)*100))
print('%0.2f percent subjects with BMI>40 (extreme obesity)'%(numpy.mean(demog.BMI>40)*100))
# Out:
# 30.65 percent subjects with BMI>30 (obese)
# 7.28 percent subjects with BMI>40 (extreme obesity)

# %%
demog.Age.hist(bins=40)
plt.title('Age')
plt.xlabel('Age (years)')
plt.ylabel('Frequency')

# %% [markdown]
# Summarize race information

# %%
print('Percentage reporting each race category')
display(demog.Race.value_counts()/demog.shape[0]*100)
# Out:
# Percentage reporting each race category
# White                                         85.632184
#  Black or African American                     6.896552
# Chinese                                        1.724138
# Other                                          1.149425
#  Vietnamese                                    0.957854
#  Filipino                                      0.766284
#  Other Asian                                   0.574713
#  Asian Indian                                  0.574713
# Choose not to respond                          0.574713
# Japanese                                       0.383142
#  Middle Eastern or North African               0.383142
# Korean                                         0.191571
#  Native Hawaiian or Other Pacific Islander     0.191571
# Name: Race, dtype: float64

# %%
demog_numeric=demog.copy()
demog_numeric=demog_numeric.select_dtypes(include=['float64','int64'])
nacount=numpy.sum(numpy.isnan(demog_numeric),0)
badcols=nacount[nacount>5]
print('dropping:',list(badcols.index))
for badcol in list(badcols.index):
    demog_numeric.drop(badcol, axis=1, inplace=True)
demog_numeric=demog_numeric.fillna(0)
dcc=demog_numeric.corr()
g=sns.clustermap(dcc,method='ward')
_=plt.setp(g.ax_heatmap.get_yticklabels(), rotation=0)
# Out:
# dropping: ['CarDebt', 'CreditCardDebt', 'EducationDebt', 'MortgageDebt', 'OtherDebtAmount', 'RetirementPercentStocks']

# %% [markdown]
# ### Health status
#
# For the psychological state variables, I binarize them so that the mean expresses the proportion of subjects reporting any level of these symptoms.

# %%
health_metadata=load_metadata('health')
healthdata=get_behav_data(dataset,'health.csv',full_dataset=True)

#pandas.read_csv(os.path.join(derived_dir,'surveydata/health.tsv'),delimiter='\t',index_col=0)
symptoms=['Nervous','Hopeless','RestlessFidgety','Depressed','EverythingIsEffort','Worthless']
for s in symptoms:
    healthdata[s]=(healthdata[s]>1).astype('int')

d=healthdata.describe().T
itemtext=[health_metadata[i]['Description'] for i in d.index]

d['Itemtext']=itemtext
display(d)
# Out:
# Getting datasets...:
#  /Users/poldrack/code/Self_Regulation_Ontology/Data/Discovery_12-05-2016
#  /Users/poldrack/code/Self_Regulation_Ontology/Data/Validation_12-05-2016
#                             count      mean       std  min  25%  50%  75%  \
# Nervous                     522.0  0.298851  0.458193  0.0  0.0  0.0  1.0
# Hopeless                    522.0  0.245211  0.430625  0.0  0.0  0.0  0.0
# RestlessFidgety             522.0  0.318008  0.466149  0.0  0.0  0.0  1.0
# Depressed                   522.0  0.203065  0.402666  0.0  0.0  0.0  0.0
# EverythingIsEffort          522.0  0.323755  0.468357  0.0  0.0  0.0  1.0
# Worthless                   522.0  0.206897  0.405469  0.0  0.0  0.0  0.0
# Last30DaysUsual             522.0  3.162835  0.954994  0.0  3.0  3.0  3.0
# DaysLostLastMonth           392.0  1.492347  3.468520 -2.0  0.0  0.0  2.0
# DaysHalfLastMonth           401.0  2.206983  3.630365 -1.0  0.0  0.0  3.0
# DoctorVisitsLastMonth       426.0  0.140845  0.747623 -3.0  0.0  0.0  0.0
# DaysPhysicalHealthFeelings  498.0  0.572289  1.000903  0.0  0.0  0.0  1.0
# NeurologicalDiagnoses       522.0  0.013410  0.115133  0.0  0.0  0.0  0.0
#
#                              max  \
# Nervous                      1.0
# Hopeless                     1.0
# RestlessFidgety              1.0
# Depressed                    1.0
# EverythingIsEffort           1.0
# Worthless                    1.0
# Last30DaysUsual              6.0
# DaysLostLastMonth           30.0
# DaysHalfLastMonth           20.0
# DoctorVisitsLastMonth       10.0
# DaysPhysicalHealthFeelings   4.0
# NeurologicalDiagnoses        1.0
#
#                                                                                                                        Itemtext
# Nervous                                                                                                            ... nervous?
# Hopeless                                                                                                          ... hopeless?
# RestlessFidgety                                                                                        ... restless or fidgety?
# Depressed                                                                     ... so depressed that nothing could cheer you up?
# EverythingIsEffort                                                                           ... that everything was an effort?
# Worthless                                                                                                        ... worthless?
# Last30DaysUsual             Q2: The last six questions asked about feelings that might have occurred during the past 30\nday...
# DaysLostLastMonth           Q3: During the past 30 days, how many days out of 30 were you totally unable to work or\ncarry o...
# DaysHalfLastMonth           Q4: Not counting the days you reported in response to Q3, how many days in the past\n30 were you...
# DoctorVisitsLastMonth       Q5: During the past 30 days, how many times did you see a doctor or other health\nprofessional a...
# DaysPhysicalHealthFeelings  Q6: During the past 30 days, how often\nhave physical health problems been\nthe main cause of th...
# NeurologicalDiagnoses                   Have you been diagnosed with any neurological disorder (e.g. Alzheimer's, Parkinson's)?

# %% [markdown]
# ### Medical diagnoses

# %%
disorders=healthdata['DiseaseDiagnoses'].unique()
ddata=[]
for d in disorders:
    diag=healthdata.query('DiseaseDiagnoses=="%s"'%d)
    ddata.append([d.lstrip(),diag.shape[0]/healthdata.shape[0]])
df=pandas.DataFrame(ddata,columns=['Diagnosis','Frequency(Percent)'])
display(df)
# Out:
#              Diagnosis  Frequency(Percent)
# 0                 None            0.827586
# 1  High Blood Pressure            0.068966
# 2   Metabolic Syndrome            0.007663
# 3               Cancer            0.005747
# 4     Type II diabetes            0.024904
# 5          Sleep Apnea            0.013410
# 6                Other            0.049808
# 7        Heart Disease            0.001916

# %% [markdown]
# ### Psychiatric diagnoses

# %%
disorders=healthdata['PsychDiagnoses'].unique()
ddata=[]
for d in disorders:
    diag=healthdata.query('PsychDiagnoses=="%s"'%d)
    ddata.append([d.lstrip(),diag.shape[0]/healthdata.shape[0]])
df=pandas.DataFrame(ddata,columns=['Diagnosis','Frequency(Percent)'])
display(df)
# Out:
#                               Diagnosis  Frequency(Percent)
# 0                                  None            0.662835
# 1                            Depression            0.193487
# 2                      Anxiety Disorder            0.053640
# 3                         Schizophrenia            0.001916
# 4                                  ADHD            0.034483
# 5                       Anorexi Nervosa            0.017241
# 6   Manic-Depressive (Bilpolar) illness            0.011494
# 7                       Drug Dependency            0.009579
# 8                                 Other            0.005747
# 9                    Alcohol Dependency            0.003831
# 10      Autism/Autism Specturm Disorder            0.001916
# 11         Obessive Compulsive Disorder            0.003831

# %% [markdown]
# ### Alcohol/Drug use

# %%
drug_metadata=load_metadata('alcohol_drugs')
drugdata=get_behav_data(dataset,'alcohol_drugs.csv',full_dataset=True)

d=drugdata.describe().T
itemtext=[drug_metadata[i]['Description'] for i in d.index]

d['Itemtext']=itemtext
display(d)
# Out:
# Getting datasets...:
#  /Users/poldrack/code/Self_Regulation_Ontology/Data/Discovery_12-05-2016
#  /Users/poldrack/code/Self_Regulation_Ontology/Data/Validation_12-05-2016
#                                             count      mean       std  min  \
# AbleToStopDrugs                             522.0  0.871648  0.334803  0.0
# AbuseMoreThanOneDrugAtATime                 522.0  0.076628  0.266256  0.0
# AlcoholHowManyDrinksDay                     522.0  1.555556  0.930285  1.0
# AlcoholHowOften                             522.0  1.526820  1.154250  0.0
# AlcoholHowOften6Drinks                      522.0  0.616858  0.892893  0.0
# BlackoutFlashbackDrugUse                    522.0  0.047893  0.213744  0.0
# CannabisConsideredReduction                 284.0  0.415493  1.119963  0.0
# CannabisHoursStoned                         261.0  0.743295  1.119411  0.0
# CannabisHowOften                            304.0  1.065789  1.531500  0.0
# CannabisPast6Months                         522.0  0.235632  0.424800  0.0
# CigsPerDay                                  522.0  0.931034  1.703286  0.0
# EngagedInIllegalActsToObtainDrugs           522.0  0.068966  0.253639  0.0
# FeelBadGuiltyDrugUse                        522.0  0.076628  0.266256  0.0
# HowLongSmoked                               522.0  2.756705  3.097923  0.0
# HowOftenCantStopCannabis                    283.0  0.187279  0.746325  0.0
# HowOftenCantStopDrinking                    522.0  0.224138  0.648009  0.0
# HowOftenDevotedTimeCannabis                 283.0  0.137809  0.551032  0.0
# HowOftenDrinkMorning                        522.0  0.082375  0.390526  0.0
# HowOftenFailedActivitiesCannabis            282.0  0.078014  0.369108  0.0
# HowOftenFailedActivitiesDrinking            522.0  0.160920  0.508059  0.0
# HowOftenGuiltRemorseDrinking                522.0  0.247126  0.611974  0.0
# HowOftenHazardousCannabis                   284.0  0.095070  0.526449  0.0
# HowOftenMemoryConcentrationProblemCannabis  284.0  0.190141  0.687425  0.0
# HowOftenUnableRememberDrinking              522.0  1.206897  0.546592  1.0
# HowSoonSmokeAfterWaking                     522.0  0.672414  1.309190  0.0
# InjuredDrinking                             522.0  1.011494  0.442318  0.0
# LifetimeSmoke100Cigs                        522.0  0.492337  0.500421  0.0
# MedicalProblemsDueToDrugUse                 522.0  0.021073  0.143765  0.0
# NeglectedFamilyDrugUse                      522.0  0.038314  0.192138  0.0
# OtherDrugs                                  522.0  0.197318  0.398356  0.0
# RelativeFriendConcernedDrinking             522.0  1.049808  0.504690  0.0
# SmokeEveryDay                               522.0  0.823755  1.186768  0.0
# SpouseParentsComplainDrugUse                522.0  0.034483  0.182641  0.0
# WidthdrawalSymptoms                         522.0  0.061303  0.240115  0.0
#
#                                             25%  50%   75%  max  \
# AbleToStopDrugs                             1.0  1.0  1.00  1.0
# AbuseMoreThanOneDrugAtATime                 0.0  0.0  0.00  1.0
# AlcoholHowManyDrinksDay                     1.0  1.0  2.00  5.0
# AlcoholHowOften                             1.0  1.0  2.00  4.0
# AlcoholHowOften6Drinks                      0.0  0.0  1.00  4.0
# BlackoutFlashbackDrugUse                    0.0  0.0  0.00  1.0
# CannabisConsideredReduction                 0.0  0.0  0.00  4.0
# CannabisHoursStoned                         0.0  0.0  1.00  4.0
# CannabisHowOften                            0.0  0.0  2.00  4.0
# CannabisPast6Months                         0.0  0.0  0.00  1.0
# CigsPerDay                                  0.0  0.0  1.00  6.0
# EngagedInIllegalActsToObtainDrugs           0.0  0.0  0.00  1.0
# FeelBadGuiltyDrugUse                        0.0  0.0  0.00  1.0
# HowLongSmoked                               0.0  0.5  6.00  7.0
# HowOftenCantStopCannabis                    0.0  0.0  0.00  4.0
# HowOftenCantStopDrinking                    0.0  0.0  0.00  4.0
# HowOftenDevotedTimeCannabis                 0.0  0.0  0.00  4.0
# HowOftenDrinkMorning                        0.0  0.0  0.00  3.0
# HowOftenFailedActivitiesCannabis            0.0  0.0  0.00  3.0
# HowOftenFailedActivitiesDrinking            0.0  0.0  0.00  4.0
# HowOftenGuiltRemorseDrinking                0.0  0.0  0.00  4.0
# HowOftenHazardousCannabis                   0.0  0.0  0.00  4.0
# HowOftenMemoryConcentrationProblemCannabis  0.0  0.0  0.00  4.0
# HowOftenUnableRememberDrinking              1.0  1.0  1.00  5.0
# HowSoonSmokeAfterWaking                     0.0  0.0  1.00  5.0
# InjuredDrinking                             1.0  1.0  1.00  3.0
# LifetimeSmoke100Cigs                        0.0  0.0  1.00  1.0
# MedicalProblemsDueToDrugUse                 0.0  0.0  0.00  1.0
# NeglectedFamilyDrugUse                      0.0  0.0  0.00  1.0
# OtherDrugs                                  0.0  0.0  0.00  1.0
# RelativeFriendConcernedDrinking             1.0  1.0  1.00  3.0
# SmokeEveryDay                               0.0  0.0  1.75  3.0
# SpouseParentsComplainDrugUse                0.0  0.0  0.00  1.0
# WidthdrawalSymptoms                         0.0  0.0  0.00  1.0
#
#                                                                                                                                        Itemtext
# AbleToStopDrugs                                   Are you always able to stop using drugs when you want to? (If never use\ndrugs, answer Yes. )
# AbuseMoreThanOneDrugAtATime                                                                          Do you abuse more than one drug at a time?
# AlcoholHowManyDrinksDay                                  How many drinks containing alcohol do you have on a typical day when you are drinking?
# AlcoholHowOften                                                                               How often do you have a drink containing alcohol?
# AlcoholHowOften6Drinks                                                                How often do you have six or more drinks on one occasion?
# BlackoutFlashbackDrugUse                                                      Have you had "blackouts" or "flashbacks" as a result of drug use?
# CannabisConsideredReduction                                        Have you ever thought about cutting down, or stopping, your use of cannabis?
# CannabisHoursStoned                                         How many hours were you stoned on\na typical day when you had been using\nCannabis?
# CannabisHowOften                                                                                                 How often do you use cannabis?
# CannabisPast6Months                                                                          Have you used any cannabis over the past 6 months?
# CigsPerDay                                                     On average, how many cigarettes do you now smoke a day (1 pack = 20 cigarettes)?
# EngagedInIllegalActsToObtainDrugs                                              Have you engaged in illegal activities in order to obtain drugs?
# FeelBadGuiltyDrugUse                                        Do you ever feel bad or guilty about your drug use? If never use drugs,\nchoose No.
# HowLongSmoked                                                                                          How long have you smoked (cumulatively)?
# HowOftenCantStopCannabis                    How often during the past six months did you find that you were not able to stop using cannabis ...
# HowOftenCantStopDrinking                    How often during the last year have you found that you were not able to stop drinking once you h...
# HowOftenDevotedTimeCannabis                 How often in the past six months have you devoted a great deal of your time to getting, using, o...
# HowOftenDrinkMorning                        How often during the last year have you needed a first drink in the morning to get yourself goin...
# HowOftenFailedActivitiesCannabis            How often during the past six months did you fail to do what was normally expected from you beca...
# HowOftenFailedActivitiesDrinking            How often during the last year have you failed to do what was normally expected from you because...
# HowOftenGuiltRemorseDrinking                          How often during the last year have you had a feeling of guilt or remorse after drinking?
# HowOftenHazardousCannabis                   How often do you use cannabis in situations that could be physically hazardous, such as driving,...
# HowOftenMemoryConcentrationProblemCannabis  How often in the past six months have you had a problem with your memory or concentration after ...
# HowOftenUnableRememberDrinking              How often during the last year have you been unable to remember what happened the night before b...
# HowSoonSmokeAfterWaking                                                           How soon after you wake up do you smoke your first cigarette?
# InjuredDrinking                                                             Have you or someone else been injured as a result of your drinking?
# LifetimeSmoke100Cigs                                       Altogether, have you smoked at least 100 or more cigarettes in your entire lifetime?
# MedicalProblemsDueToDrugUse                 Have you had medical problems as a result of your drug use (e.g.,\nmemory loss, hepatitis, convu...
# NeglectedFamilyDrugUse                                                             Have you neglected your family because of your use of drugs?
# OtherDrugs                                                                   Have you used drugs other than those required for medical reasons?
# RelativeFriendConcernedDrinking             Has a relative or friend or a doctor or another health worker been concerned about your drinking...
# SmokeEveryDay                                                                   Do you now smoke cigarettes every day, some days or not at all?
# SpouseParentsComplainDrugUse                                    Does your spouse (or parents) ever complain about your involvement\nwith drugs?
# WidthdrawalSymptoms                                   Have you ever experienced withdrawal symptoms (felt sick) when you\nstopped taking drugs?

# %%
print('Percentage of lifetime smokers (100 cigs): %0.2f'%(100*numpy.mean(drugdata.LifetimeSmoke100Cigs>0)))
print('Percentage of current smokers: %0.2f'%(100*numpy.mean(drugdata.CigsPerDay>0)))
print('Percentage of cannabis users (at all): %0.2f'%(100*numpy.mean(drugdata.CannabisHowOften>0)))
print('Percentage of cannabis users (at least once/month): %0.2f'%(100*numpy.mean(drugdata.CannabisHowOften>1)))
print('Percentage of daily cannabis users: %0.2f'%(100*numpy.mean(drugdata.CannabisHowOften>3)))
q=drugdata.query('AlcoholHowOften>3 & AlcoholHowManyDrinksDay>1')
print('Percentage of heavy drinkers (4+ times per week, 3+ drinks per time): %0.2f'%(100*float(q.shape[0]/drugdata.shape[0])))
print('Percentage reporting trouble stopping their drinking: %0.2f'%(100*numpy.mean(drugdata.HowOftenCantStopDrinking>3)))
# Out:
# Percentage of lifetime smokers (100 cigs): 49.23
# Percentage of current smokers: 27.78
# Percentage of cannabis users (at all): 24.33
# Percentage of cannabis users (at least once/month): 14.94
# Percentage of daily cannabis users: 9.58
# Percentage of heavy drinkers (4+ times per week, 3+ drinks per time): 4.60
# Percentage reporting trouble stopping their drinking: 0.57

# %%
print('Cigarettes smoked per day')
cigdata=[]
for i in drug_metadata['CigsPerDay']['Levels']:
    q=drugdata.query('CigsPerDay == %d'%float(i))
    cigdata.append([int(i),drug_metadata['CigsPerDay']['Levels'][i],q.shape[0]])
df=pandas.DataFrame(cigdata,columns=['Resp','Frequency','Proportion'])
df=df.sort_values(by='Resp')
display(df)
# Out:
# Cigarettes smoked per day
#    Resp                    Frequency  Proportion
# 7     0                I don't smoke         377
# 2     1  Less than a cigarette a day          27
# 6     2                           <5          16
# 3     3                         5-10          28
# 5     4                        10-20          34
# 4     5                       1 pack          33
# 1     6                      2 packs           7
# 0     7            More than 2 packs           0

# %% [markdown]
# ### QA analyses for demographic data
#
# The files are saved as PDF rather than printed, to make them easier to look at in high resolution, since Jupyter doesn't do a great job of displaying R output.

# %%
ncols=5
for i in range(numpy.ceil(demog.shape[1]/ncols).astype('int')):
    start=i*ncols
    end=(i+1)*ncols
    subset=demog.ix[:,start:end].copy()
    subset = subset.dropna(how = 'all').dropna(axis = 0)
    p = sns.pairplot(subset, kind = 'reg', size = 5, diag_kws = {'bins': 50})

# %% [markdown]
# ### Factor analyses of demographic/health data

# %%
demog_ord=pandas.read_csv(os.path.join(derived_dir,'surveydata/demographics_ordinal.tsv'),delimiter='\t',index_col=0)
demog_ord['BMI']=demog_ord['WeightPounds']*0.45 / (demog_ord['HeightInches']*0.025)**2
del demog_ord['WeightPounds']
del demog_ord['HeightInches']

healthdata_ord=pandas.read_csv(os.path.join(derived_dir,'surveydata/health_ordinal.tsv'),delimiter='\t',index_col=0)
drugdata_ord=pandas.read_csv(os.path.join(derived_dir,'surveydata/alcohol_drugs_ordinal.tsv'),delimiter='\t',index_col=0)

all_data=demog_ord.merge(healthdata_ord,left_index=True,right_index=True)
all_data=all_data.merge(drugdata_ord,left_index=True,right_index=True)

# drop some bad variables, due to highly skewed distributions
dropvars=[]
threshold=0.1
for v in all_data.columns:
    if all_data[v].mean()<threshold:
        dropvars.append(v)
print('dropping:',dropvars)
for d in dropvars:
    del all_data[d]

all_data.shape
cdata=numpy.array(all_data)
goodvars=numpy.sum(numpy.isnan(cdata),0)==0
cdata=cdata[:,goodvars]
varnames_all_data=list(all_data.columns)
varnames=[varnames_all_data[i] for i in range(len(varnames_all_data)) if goodvars[i]]
print(cdata.shape)

# %%
# %%R -i cdata,varnames
# library(psych)
# df=data.frame(cdata)
# names(df)=varnames
# pdf(file='iclust.pdf',width=16, height=16)
# ic=iclust(df)
# iclust.diagram(ic,cex=1.5)
# dev.off()
