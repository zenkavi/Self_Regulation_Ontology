# %% [markdown]
# # Self Regulation Ontology Project
#
# This file will start with a basic introduction to expanalysis and the python commands one would probably want to interact with expfactory data. I have also included some helper functions I have found useful that are not part of expanalysis proper. I'll make use of basic python commands along the way without explaining them. Hopefully you can understand them in context (or else google them!)
#
# **Table of Contents**
# - Loading Data
# - Basic expanalysis
# - Pandas intro
# - Other functions

# %% [markdown]
# ## Loading Data
#
# Data is stored on an AWS server. To access the data we use expanalysis. I created a helper function that makes loading data a little easier.

# %%
from expanalysis.results import Result, get_filters

def load_data(access_token, data_loc, source = 'file', filters = None):
    if source == 'file':
        results = Result(filters = filters)
        results.load_results(data_loc)
    elif source == 'web':
        #Load Results from Database
        results = Result(access_token, filters = filters)
        results.export(data_loc + '.json')
    data = results.data
    return data

# %% [markdown]
# Expanalysis raw data comes with many identifiers that are not important for the kind of analysis we are doing. For instance, we don't care about the cognitive atlas ID. Others may be important at some stage (the experiment_version), but the hope/plan is that for any particular experiment all collected data is using the same experiment version.
#
# Do remove columns we don't care about we will define a filter. This is a dictionary that specifies some expanalysis columns and what to do with them. Here we just want to drop them
#
# After that we need to specify an access token. I am loading it from a directory.
#
# Finally, loading data from the web takes a loooong time. Since we will be working with more-or-less the same data time and time again, it makes sense to save it somewhere (this is what the helper function above does). So I specify a location to use.

# %%
#set up filters
filters = get_filters()
drop_columns = ['battery_description', 'experiment_reference', 'experiment_version', \
         'experiment_name','experiment_cognitive_atlas_task']
for col in drop_columns:
    filters[col] = {'drop': True}

                  
f = open('/home/ian/Experiments/expfactory/docs/expfactory_token.txt')
access_token = f.read().strip()      
data_loc = '/home/ian/Experiments/expfactory/Self_Regulation_Ontology/Data/Pilot_Results'

# %% [markdown]
# Now with all of that specified we can load the data. If you are loading the data for the first time, or want the most up-to-date data, set `source` to 'web'. Otherwise set it to 'file'

# %%
source_data = load_data(access_token, data_loc, filters = filters, source = 'file')
# Out:
# Empty datasets found! See Results.empty field

# %% [markdown]
# So that gives you a dataframe that houses your data. Yay! Let's look at what it looks like:

# %%
print 'Dimensions (Rows x Cols):', source_data.shape
print '\nColumns:'
print source_data.columns
# Out:
# Dimensions (Rows x Cols): (3497, 8)
#
# Columns:
# Index([         u'finishtime',        u'battery_name',           u'worker_id',
#                   u'platform', u'experiment_template',   u'experiment_exp_id',
#                       u'data',             u'browser'],
#       dtype='object')

# %% [markdown]
# Each row is one subject's data for one task. The columns are self-explanatory. The import things to note is that _all the data_ is in one column - the data column. Let's look at one row's data column.

# %%
print source_data.iloc[1]['experiment_exp_id']
print type(source_data.iloc[1]['data'])
source_data.iloc[1]['data']
# Out:
# angling_risk_task_always_sunny
# <type 'list'>
# [{u'current_trial': 0,
#   u'dateTime': 1460134802612,
#   u'trialdata': {u'internal_node_id': u'0.0-0.0-0.0',
#    u'key_press': 13,
#    u'rt': 29250,
#    u'time_elapsed': 29251,
#    u'trial_id': u'instruction',
#    u'trial_index': 0,
#    u'trial_type': u'poldrack-text'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 1,
#   u'dateTime': 1460134840600,
#   u'trialdata': {u'internal_node_id': u'0.0-0.0-1.0',
#    u'rt': 37968,
#    u'time_elapsed': 67229,
#    u'trial_id': u'instruction',
#    u'trial_index': 1,
#    u'trial_type': u'poldrack-instructions',
#    u'view_history': u'[{"page_index":0,"viewing_time":37968}]'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 2,
#   u'dateTime': 1460134902643,
#   u'trialdata': {u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-1.0',
#    u'key_press': 13,
#    u'release': u'Keep',
#    u'rt': 61037,
#    u'time_elapsed': 129282,
#    u'trial_id': u'intro',
#    u'trial_index': 2,
#    u'trial_type': u'poldrack-text',
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 3,
#   u'dateTime': 1460134919820,
#   u'trialdata': {u'internal_node_id': u'0.0-2.0',
#    u'responses': u'{"Q0":"100"}',
#    u'rt': 16173,
#    u'time_elapsed': 146459,
#    u'trial_id': u'ask fish',
#    u'trial_index': 3,
#    u'trial_type': u'survey-text'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 4,
#   u'dateTime': 1460134920838,
#   u'trialdata': {u'internal_node_id': u'0.0-3.0',
#    u'time_elapsed': 147477,
#    u'trial_id': u'set_fish',
#    u'trial_index': 4,
#    u'trial_type': u'call-function'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 5,
#   u'dateTime': 1460134930421,
#   u'trialdata': {u'block_duration': 9494,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.0-0.0',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 100,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 9494,
#    u'stim_duration': 9494,
#    u'time_elapsed': 157060,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 5,
#    u'trial_num': 0,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 0,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 6,
#   u'dateTime': 1460134935204,
#   u'trialdata': {u'block_duration': 4720,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.1-0.1',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 99,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 4720,
#    u'stim_duration': 4720,
#    u'time_elapsed': 161843,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 6,
#    u'trial_num': 1,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 1,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 7,
#   u'dateTime': 1460134939021,
#   u'trialdata': {u'block_duration': 3759,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.2-0.2',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 98,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 3759,
#    u'stim_duration': 3759,
#    u'time_elapsed': 165660,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 7,
#    u'trial_num': 2,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 2,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 8,
#   u'dateTime': 1460134941684,
#   u'trialdata': {u'block_duration': 2571,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.3-0.3',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 97,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 2571,
#    u'stim_duration': 2571,
#    u'time_elapsed': 168323,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 8,
#    u'trial_num': 3,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 3,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 9,
#   u'dateTime': 1460134944202,
#   u'trialdata': {u'block_duration': 2446,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.4-0.4',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 96,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 2446,
#    u'stim_duration': 2446,
#    u'time_elapsed': 170841,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 9,
#    u'trial_num': 4,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 4,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 10,
#   u'dateTime': 1460134946780,
#   u'trialdata': {u'block_duration': 2520,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.5-0.5',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 95,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 2520,
#    u'stim_duration': 2520,
#    u'time_elapsed': 173419,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 10,
#    u'trial_num': 5,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 5,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 11,
#   u'dateTime': 1460134948807,
#   u'trialdata': {u'block_duration': 1966,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.6-0.6',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 94,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 1966,
#    u'stim_duration': 1966,
#    u'time_elapsed': 175446,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 11,
#    u'trial_num': 6,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 6,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 12,
#   u'dateTime': 1460134950357,
#   u'trialdata': {u'block_duration': 1495,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.7-0.7',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 93,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 1495,
#    u'stim_duration': 1495,
#    u'time_elapsed': 176996,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 12,
#    u'trial_num': 7,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 7,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 13,
#   u'dateTime': 1460134951385,
#   u'trialdata': {u'block_duration': 988,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.8-0.8',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 92,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 988,
#    u'stim_duration': 988,
#    u'time_elapsed': 178024,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 13,
#    u'trial_num': 8,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 8,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 14,
#   u'dateTime': 1460134952320,
#   u'trialdata': {u'block_duration': 867,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.9-0.9',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 91,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 867,
#    u'stim_duration': 867,
#    u'time_elapsed': 178959,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 14,
#    u'trial_num': 9,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 9,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 15,
#   u'dateTime': 1460134953250,
#   u'trialdata': {u'block_duration': 882,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.10-0.10',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 90,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 882,
#    u'stim_duration': 882,
#    u'time_elapsed': 179889,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 15,
#    u'trial_num': 10,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 10,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 16,
#   u'dateTime': 1460134954237,
#   u'trialdata': {u'block_duration': 910,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.11-0.11',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 89,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 910,
#    u'stim_duration': 910,
#    u'time_elapsed': 180876,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 16,
#    u'trial_num': 11,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 11,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 17,
#   u'dateTime': 1460134955084,
#   u'trialdata': {u'block_duration': 797,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.12-0.12',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 88,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 797,
#    u'stim_duration': 797,
#    u'time_elapsed': 181723,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 17,
#    u'trial_num': 12,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 12,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 18,
#   u'dateTime': 1460134955884,
#   u'trialdata': {u'block_duration': 743,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.13-0.13',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 87,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 743,
#    u'stim_duration': 743,
#    u'time_elapsed': 182523,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 18,
#    u'trial_num': 13,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 13,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 19,
#   u'dateTime': 1460134956770,
#   u'trialdata': {u'block_duration': 825,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.14-0.14',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 86,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 825,
#    u'stim_duration': 825,
#    u'time_elapsed': 183409,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 19,
#    u'trial_num': 14,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 14,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 20,
#   u'dateTime': 1460134957517,
#   u'trialdata': {u'block_duration': 701,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.15-0.15',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 85,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 701,
#    u'stim_duration': 701,
#    u'time_elapsed': 184156,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 20,
#    u'trial_num': 15,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 15,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 21,
#   u'dateTime': 1460134958394,
#   u'trialdata': {u'block_duration': 821,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.16-0.16',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 84,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 821,
#    u'stim_duration': 821,
#    u'time_elapsed': 185033,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 21,
#    u'trial_num': 16,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 16,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 22,
#   u'dateTime': 1460134959194,
#   u'trialdata': {u'block_duration': 743,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.17-0.17',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 83,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 743,
#    u'stim_duration': 743,
#    u'time_elapsed': 185833,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 22,
#    u'trial_num': 17,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 17,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 23,
#   u'dateTime': 1460134960327,
#   u'trialdata': {u'block_duration': 1082,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.18-0.18',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 82,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 1082,
#    u'stim_duration': 1082,
#    u'time_elapsed': 186966,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 23,
#    u'trial_num': 18,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 18,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 24,
#   u'dateTime': 1460134961207,
#   u'trialdata': {u'block_duration': 847,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.19-0.19',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 81,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 847,
#    u'stim_duration': 847,
#    u'time_elapsed': 187846,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 24,
#    u'trial_num': 19,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 19,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 25,
#   u'dateTime': 1460134962043,
#   u'trialdata': {u'block_duration': 777,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.20-0.20',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 80,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 777,
#    u'stim_duration': 777,
#    u'time_elapsed': 188682,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 25,
#    u'trial_num': 20,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 20,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 26,
#   u'dateTime': 1460134962900,
#   u'trialdata': {u'block_duration': 800,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.21-0.21',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 79,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 800,
#    u'stim_duration': 800,
#    u'time_elapsed': 189539,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 26,
#    u'trial_num': 21,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 21,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 27,
#   u'dateTime': 1460134965044,
#   u'trialdata': {u'block_duration': 2088,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-4.22-0.22',
#    u'mouse_click': u'Collect',
#    u'red_fish_num': 78,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 2088,
#    u'stim_duration': 2088,
#    u'time_elapsed': 191683,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 27,
#    u'trial_num': 22,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 22,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 28,
#   u'dateTime': 1460134971167,
#   u'trialdata': {u'internal_node_id': u'0.0-5.0',
#    u'key_press': 13,
#    u'rt': 6123,
#    u'time_elapsed': 197806,
#    u'trial_id': u'round_over',
#    u'trial_index': 28,
#    u'trial_type': u'poldrack-text'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 29,
#   u'dateTime': 1460134975996,
#   u'trialdata': {u'block_duration': 4759,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.0-0.0',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 100,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 4759,
#    u'stim_duration': 4759,
#    u'time_elapsed': 202635,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 29,
#    u'trial_num': 0,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 0,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 30,
#   u'dateTime': 1460134977084,
#   u'trialdata': {u'block_duration': 1031,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.1-0.1',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 99,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 1031,
#    u'stim_duration': 1031,
#    u'time_elapsed': 203723,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 30,
#    u'trial_num': 1,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 1,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 31,
#   u'dateTime': 1460134978010,
#   u'trialdata': {u'block_duration': 864,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.2-0.2',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 98,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 864,
#    u'stim_duration': 864,
#    u'time_elapsed': 204649,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 31,
#    u'trial_num': 2,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 2,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 32,
#   u'dateTime': 1460134978887,
#   u'trialdata': {u'block_duration': 825,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.3-0.3',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 97,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 825,
#    u'stim_duration': 825,
#    u'time_elapsed': 205526,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 32,
#    u'trial_num': 3,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 3,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 33,
#   u'dateTime': 1460134979870,
#   u'trialdata': {u'block_duration': 932,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.4-0.4',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 96,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 932,
#    u'stim_duration': 932,
#    u'time_elapsed': 206509,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 33,
#    u'trial_num': 4,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 4,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 34,
#   u'dateTime': 1460134980810,
#   u'trialdata': {u'block_duration': 869,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.5-0.5',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 95,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 869,
#    u'stim_duration': 869,
#    u'time_elapsed': 207449,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 34,
#    u'trial_num': 5,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 5,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 35,
#   u'dateTime': 1460134981737,
#   u'trialdata': {u'block_duration': 869,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.6-0.6',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 94,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 869,
#    u'stim_duration': 869,
#    u'time_elapsed': 208376,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 35,
#    u'trial_num': 6,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 6,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 36,
#   u'dateTime': 1460134982620,
#   u'trialdata': {u'block_duration': 834,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.7-0.7',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 93,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 834,
#    u'stim_duration': 834,
#    u'time_elapsed': 209259,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 36,
#    u'trial_num': 7,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 7,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 37,
#   u'dateTime': 1460134983500,
#   u'trialdata': {u'block_duration': 826,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.8-0.8',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 92,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 826,
#    u'stim_duration': 826,
#    u'time_elapsed': 210139,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 37,
#    u'trial_num': 8,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 8,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 38,
#   u'dateTime': 1460134984295,
#   u'trialdata': {u'block_duration': 734,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.9-0.9',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 91,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 734,
#    u'stim_duration': 734,
#    u'time_elapsed': 210934,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 38,
#    u'trial_num': 9,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 9,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 39,
#   u'dateTime': 1460134985123,
#   u'trialdata': {u'block_duration': 765,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.10-0.10',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 90,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 765,
#    u'stim_duration': 765,
#    u'time_elapsed': 211762,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 39,
#    u'trial_num': 10,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 10,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 40,
#   u'dateTime': 1460134985893,
#   u'trialdata': {u'block_duration': 721,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.11-0.11',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 89,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 721,
#    u'stim_duration': 721,
#    u'time_elapsed': 212532,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 40,
#    u'trial_num': 11,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 11,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 41,
#   u'dateTime': 1460134986627,
#   u'trialdata': {u'block_duration': 674,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.12-0.12',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 88,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 674,
#    u'stim_duration': 674,
#    u'time_elapsed': 213266,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 41,
#    u'trial_num': 12,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 12,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 42,
#   u'dateTime': 1460134987511,
#   u'trialdata': {u'block_duration': 828,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.13-0.13',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 87,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 828,
#    u'stim_duration': 828,
#    u'time_elapsed': 214150,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 42,
#    u'trial_num': 13,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 13,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 43,
#   u'dateTime': 1460134988657,
#   u'trialdata': {u'block_duration': 1072,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.14-0.14',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 86,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 1072,
#    u'stim_duration': 1072,
#    u'time_elapsed': 215296,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 43,
#    u'trial_num': 14,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 14,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 44,
#   u'dateTime': 1460134989488,
#   u'trialdata': {u'block_duration': 767,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.15-0.15',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 85,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 767,
#    u'stim_duration': 767,
#    u'time_elapsed': 216127,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 44,
#    u'trial_num': 15,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 15,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 45,
#   u'dateTime': 1460134990252,
#   u'trialdata': {u'block_duration': 732,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.16-0.16',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 84,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 732,
#    u'stim_duration': 732,
#    u'time_elapsed': 216891,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 45,
#    u'trial_num': 16,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 16,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 46,
#   u'dateTime': 1460134991104,
#   u'trialdata': {u'block_duration': 781,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.17-0.17',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 83,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 781,
#    u'stim_duration': 781,
#    u'time_elapsed': 217743,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 46,
#    u'trial_num': 17,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 17,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 47,
#   u'dateTime': 1460134991891,
#   u'trialdata': {u'block_duration': 736,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.18-0.18',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 82,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 736,
#    u'stim_duration': 736,
#    u'time_elapsed': 218530,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 47,
#    u'trial_num': 18,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 18,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 48,
#   u'dateTime': 1460134992639,
#   u'trialdata': {u'block_duration': 692,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.19-0.19',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 81,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 692,
#    u'stim_duration': 692,
#    u'time_elapsed': 219278,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 48,
#    u'trial_num': 19,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 19,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 49,
#   u'dateTime': 1460134996362,
#   u'trialdata': {u'block_duration': 3663,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.20-0.20',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 80,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 3663,
#    u'stim_duration': 3663,
#    u'time_elapsed': 223001,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 49,
#    u'trial_num': 20,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 20,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 50,
#   u'dateTime': 1460134997247,
#   u'trialdata': {u'block_duration': 827,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.21-0.21',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 79,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 827,
#    u'stim_duration': 827,
#    u'time_elapsed': 223886,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 50,
#    u'trial_num': 21,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 21,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 51,
#   u'dateTime': 1460134997957,
#   u'trialdata': {u'block_duration': 665,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.22-0.22',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 78,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 665,
#    u'stim_duration': 665,
#    u'time_elapsed': 224596,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 51,
#    u'trial_num': 22,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 22,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 52,
#   u'dateTime': 1460134998674,
#   u'trialdata': {u'block_duration': 667,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.23-0.23',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 77,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 667,
#    u'stim_duration': 667,
#    u'time_elapsed': 225313,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 52,
#    u'trial_num': 23,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 23,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 53,
#   u'dateTime': 1460134999524,
#   u'trialdata': {u'block_duration': 784,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.24-0.24',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 76,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 784,
#    u'stim_duration': 784,
#    u'time_elapsed': 226163,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 53,
#    u'trial_num': 24,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 24,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 54,
#   u'dateTime': 1460135000235,
#   u'trialdata': {u'block_duration': 662,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.25-0.25',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 75,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 662,
#    u'stim_duration': 662,
#    u'time_elapsed': 226874,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 54,
#    u'trial_num': 25,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 25,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 55,
#   u'dateTime': 1460135001551,
#   u'trialdata': {u'block_duration': 1265,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.26-0.26',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 74,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 1265,
#    u'stim_duration': 1265,
#    u'time_elapsed': 228190,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 55,
#    u'trial_num': 26,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 26,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 56,
#   u'dateTime': 1460135003161,
#   u'trialdata': {u'block_duration': 1555,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.27-0.27',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 73,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 1555,
#    u'stim_duration': 1555,
#    u'time_elapsed': 229800,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 56,
#    u'trial_num': 27,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 27,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 57,
#   u'dateTime': 1460135003778,
#   u'trialdata': {u'block_duration': 564,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.28-0.28',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 72,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 564,
#    u'stim_duration': 564,
#    u'time_elapsed': 230417,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 57,
#    u'trial_num': 28,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 28,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 58,
#   u'dateTime': 1460135004591,
#   u'trialdata': {u'block_duration': 761,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.29-0.29',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 71,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 761,
#    u'stim_duration': 761,
#    u'time_elapsed': 231230,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 58,
#    u'trial_num': 29,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 29,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 59,
#   u'dateTime': 1460135005394,
#   u'trialdata': {u'block_duration': 751,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.30-0.30',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 70,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 751,
#    u'stim_duration': 751,
#    u'time_elapsed': 232033,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 59,
#    u'trial_num': 30,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 30,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 60,
#   u'dateTime': 1460135005973,
#   u'trialdata': {u'block_duration': 524,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.31-0.31',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 69,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 524,
#    u'stim_duration': 524,
#    u'time_elapsed': 232612,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 60,
#    u'trial_num': 31,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 31,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 61,
#   u'dateTime': 1460135006594,
#   u'trialdata': {u'block_duration': 556,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.32-0.32',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 68,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 556,
#    u'stim_duration': 556,
#    u'time_elapsed': 233233,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 61,
#    u'trial_num': 32,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 32,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 62,
#   u'dateTime': 1460135007481,
#   u'trialdata': {u'block_duration': 824,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.33-0.33',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 67,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 824,
#    u'stim_duration': 824,
#    u'time_elapsed': 234120,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 62,
#    u'trial_num': 33,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 33,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 63,
#   u'dateTime': 1460135008050,
#   u'trialdata': {u'block_duration': 514,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.34-0.34',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 66,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 514,
#    u'stim_duration': 514,
#    u'time_elapsed': 234689,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 63,
#    u'trial_num': 34,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 34,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 64,
#   u'dateTime': 1460135008584,
#   u'trialdata': {u'block_duration': 476,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.35-0.35',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 65,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 476,
#    u'stim_duration': 476,
#    u'time_elapsed': 235223,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 64,
#    u'trial_num': 35,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 35,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 65,
#   u'dateTime': 1460135009521,
#   u'trialdata': {u'block_duration': 890,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.36-0.36',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 64,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 890,
#    u'stim_duration': 890,
#    u'time_elapsed': 236160,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 65,
#    u'trial_num': 36,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 36,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 66,
#   u'dateTime': 1460135010284,
#   u'trialdata': {u'block_duration': 700,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.37-0.37',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 63,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 700,
#    u'stim_duration': 700,
#    u'time_elapsed': 236923,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 66,
#    u'trial_num': 37,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 37,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 67,
#   u'dateTime': 1460135010977,
#   u'trialdata': {u'block_duration': 638,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.38-0.38',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 62,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 638,
#    u'stim_duration': 638,
#    u'time_elapsed': 237616,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 67,
#    u'trial_num': 38,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 38,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 68,
#   u'dateTime': 1460135011821,
#   u'trialdata': {u'block_duration': 800,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.39-0.39',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 61,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 800,
#    u'stim_duration': 800,
#    u'time_elapsed': 238460,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 68,
#    u'trial_num': 39,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 39,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 69,
#   u'dateTime': 1460135022106,
#   u'trialdata': {u'block_duration': 10241,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.40-0.40',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 60,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 10241,
#    u'stim_duration': 10241,
#    u'time_elapsed': 248745,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 69,
#    u'trial_num': 40,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 40,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 70,
#   u'dateTime': 1460135022781,
#   u'trialdata': {u'block_duration': 626,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.41-0.41',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 59,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 626,
#    u'stim_duration': 626,
#    u'time_elapsed': 249420,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 70,
#    u'trial_num': 41,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 41,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 71,
#   u'dateTime': 1460135023376,
#   u'trialdata': {u'block_duration': 549,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.42-0.42',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 58,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 549,
#    u'stim_duration': 549,
#    u'time_elapsed': 250015,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 71,
#    u'trial_num': 42,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 42,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 72,
#   u'dateTime': 1460135023966,
#   u'trialdata': {u'block_duration': 543,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.43-0.43',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 57,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 543,
#    u'stim_duration': 543,
#    u'time_elapsed': 250605,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 72,
#    u'trial_num': 43,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 43,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 73,
#   u'dateTime': 1460135024679,
#   u'trialdata': {u'block_duration': 664,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.44-0.44',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 56,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 664,
#    u'stim_duration': 664,
#    u'time_elapsed': 251318,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 73,
#    u'trial_num': 44,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 44,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 74,
#   u'dateTime': 1460135025333,
#   u'trialdata': {u'block_duration': 607,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.45-0.45',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 55,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 607,
#    u'stim_duration': 607,
#    u'time_elapsed': 251972,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 74,
#    u'trial_num': 45,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 45,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 75,
#   u'dateTime': 1460135026609,
#   u'trialdata': {u'block_duration': 1231,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.46-0.46',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 54,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 1231,
#    u'stim_duration': 1231,
#    u'time_elapsed': 253248,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 75,
#    u'trial_num': 46,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 46,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 76,
#   u'dateTime': 1460135027309,
#   u'trialdata': {u'block_duration': 649,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.47-0.47',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 53,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 649,
#    u'stim_duration': 649,
#    u'time_elapsed': 253948,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 76,
#    u'trial_num': 47,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 47,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 77,
#   u'dateTime': 1460135028113,
#   u'trialdata': {u'block_duration': 758,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.48-0.48',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 52,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 758,
#    u'stim_duration': 758,
#    u'time_elapsed': 254752,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 77,
#    u'trial_num': 48,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 48,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 78,
#   u'dateTime': 1460135029309,
#   u'trialdata': {u'block_duration': 1154,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.49-0.49',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 51,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 1154,
#    u'stim_duration': 1154,
#    u'time_elapsed': 255948,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 78,
#    u'trial_num': 49,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 49,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 79,
#   u'dateTime': 1460135036549,
#   u'trialdata': {u'block_duration': 7200,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-6.50-0.50',
#    u'mouse_click': u'Collect',
#    u'red_fish_num': 50,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 7200,
#    u'stim_duration': 7200,
#    u'time_elapsed': 263188,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 22,
#    u'trial_id': u'stim',
#    u'trial_index': 79,
#    u'trial_num': 50,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 50,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 80,
#   u'dateTime': 1460135040925,
#   u'trialdata': {u'internal_node_id': u'0.0-7.0',
#    u'key_press': 13,
#    u'rt': 4366,
#    u'time_elapsed': 267564,
#    u'trial_id': u'round_over',
#    u'trial_index': 80,
#    u'trial_type': u'poldrack-text'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 81,
#   u'dateTime': 1460135086060,
#   u'trialdata': {u'internal_node_id': u'0.0-8.0',
#    u'rt': 45114,
#    u'time_elapsed': 312699,
#    u'trial_id': u'instruction',
#    u'trial_index': 81,
#    u'trial_type': u'poldrack-instructions',
#    u'view_history': u'[{"page_index":0,"viewing_time":19670},{"page_index":1,"viewing_time":14117},{"page_index":2,"viewing_time":11327}]'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 82,
#   u'dateTime': 1460135095693,
#   u'trialdata': {u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-9.0',
#    u'key_press': 13,
#    u'release': u'Release',
#    u'rt': 8618,
#    u'time_elapsed': 322332,
#    u'trial_id': u'intro',
#    u'trial_index': 82,
#    u'trial_type': u'poldrack-text',
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 83,
#   u'dateTime': 1460135104764,
#   u'trialdata': {u'internal_node_id': u'0.0-10.0',
#    u'responses': u'{"Q0":"100"}',
#    u'rt': 8044,
#    u'time_elapsed': 331403,
#    u'trial_id': u'ask fish',
#    u'trial_index': 83,
#    u'trial_type': u'survey-text'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 84,
#   u'dateTime': 1460135105781,
#   u'trialdata': {u'internal_node_id': u'0.0-11.0',
#    u'time_elapsed': 332420,
#    u'trial_id': u'set_fish',
#    u'trial_index': 84,
#    u'trial_type': u'call-function'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 85,
#   u'dateTime': 1460135111681,
#   u'trialdata': {u'block_duration': 5827,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-12.0-0.0',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 100,
#    u'release': u'Release',
#    u'round_num': 0,
#    u'rt': 5827,
#    u'stim_duration': 5827,
#    u'time_elapsed': 338320,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 85,
#    u'trial_num': 0,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 0,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 86,
#   u'dateTime': 1460135112377,
#   u'trialdata': {u'block_duration': 631,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-12.1-0.1',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 100,
#    u'release': u'Release',
#    u'round_num': 0,
#    u'rt': 631,
#    u'stim_duration': 631,
#    u'time_elapsed': 339015,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 86,
#    u'trial_num': 1,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 1,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 87,
#   u'dateTime': 1460135113042,
#   u'trialdata': {u'block_duration': 604,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-12.2-0.2',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 100,
#    u'release': u'Release',
#    u'round_num': 0,
#    u'rt': 604,
#    u'stim_duration': 604,
#    u'time_elapsed': 339681,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 87,
#    u'trial_num': 2,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 2,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 88,
#   u'dateTime': 1460135113699,
#   u'trialdata': {u'block_duration': 585,
#    u'exp_stage': u'practice',
#    u'internal_node_id': u'0.0-12.3-0.3',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 100,
#    u'release': u'Release',
#    u'round_num': 0,
#    u'rt': 585,
#    u'stim_duration': 585,
#    u'time_elapsed': 340328,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 88,
#    u'trial_num': 3,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 3,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 89,
#   u'dateTime': 1460135114283,
#   u'trialdata': {u'block_duration': 518,
#    u'exp_stage': u'practice',
# ...
#    u'red_fish_num': 83,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 157,
#    u'stim_duration': 157,
#    u'time_elapsed': 984093,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 971,
#    u'trial_num': 44,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 44,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 972,
#   u'dateTime': 1460135757699,
#   u'trialdata': {u'block_duration': 177,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.45-0.45',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 82,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 177,
#    u'stim_duration': 177,
#    u'time_elapsed': 984338,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 972,
#    u'trial_num': 45,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 45,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 973,
#   u'dateTime': 1460135757900,
#   u'trialdata': {u'block_duration': 126,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.46-0.46',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 81,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 126,
#    u'stim_duration': 126,
#    u'time_elapsed': 984539,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 973,
#    u'trial_num': 46,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 46,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 974,
#   u'dateTime': 1460135758145,
#   u'trialdata': {u'block_duration': 169,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.47-0.47',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 80,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 169,
#    u'stim_duration': 169,
#    u'time_elapsed': 984784,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 974,
#    u'trial_num': 47,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 47,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 975,
#   u'dateTime': 1460135758408,
#   u'trialdata': {u'block_duration': 200,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.48-0.48',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 79,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 200,
#    u'stim_duration': 200,
#    u'time_elapsed': 985047,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 975,
#    u'trial_num': 48,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 48,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 976,
#   u'dateTime': 1460135758644,
#   u'trialdata': {u'block_duration': 156,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.49-0.49',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 78,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 156,
#    u'stim_duration': 156,
#    u'time_elapsed': 985283,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 976,
#    u'trial_num': 49,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 49,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 977,
#   u'dateTime': 1460135758900,
#   u'trialdata': {u'block_duration': 201,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.50-0.50',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 77,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 201,
#    u'stim_duration': 201,
#    u'time_elapsed': 985539,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 977,
#    u'trial_num': 50,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 50,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 978,
#   u'dateTime': 1460135759192,
#   u'trialdata': {u'block_duration': 197,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.51-0.51',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 76,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 197,
#    u'stim_duration': 197,
#    u'time_elapsed': 985831,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 978,
#    u'trial_num': 51,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 51,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 979,
#   u'dateTime': 1460135759415,
#   u'trialdata': {u'block_duration': 158,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.52-0.52',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 75,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 158,
#    u'stim_duration': 158,
#    u'time_elapsed': 986054,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 979,
#    u'trial_num': 52,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 52,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 980,
#   u'dateTime': 1460135759656,
#   u'trialdata': {u'block_duration': 175,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.53-0.53',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 74,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 175,
#    u'stim_duration': 175,
#    u'time_elapsed': 986295,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 980,
#    u'trial_num': 53,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 53,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 981,
#   u'dateTime': 1460135759911,
#   u'trialdata': {u'block_duration': 190,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.54-0.54',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 73,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 190,
#    u'stim_duration': 190,
#    u'time_elapsed': 986550,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 981,
#    u'trial_num': 54,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 54,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 982,
#   u'dateTime': 1460135760163,
#   u'trialdata': {u'block_duration': 185,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.55-0.55',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 72,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 185,
#    u'stim_duration': 185,
#    u'time_elapsed': 986802,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 982,
#    u'trial_num': 55,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 55,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 983,
#   u'dateTime': 1460135760407,
#   u'trialdata': {u'block_duration': 164,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.56-0.56',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 71,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 164,
#    u'stim_duration': 164,
#    u'time_elapsed': 987046,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 983,
#    u'trial_num': 56,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 56,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 984,
#   u'dateTime': 1460135760920,
#   u'trialdata': {u'block_duration': 439,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.57-0.57',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 70,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 439,
#    u'stim_duration': 439,
#    u'time_elapsed': 987559,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 984,
#    u'trial_num': 57,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 57,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 985,
#   u'dateTime': 1460135761201,
#   u'trialdata': {u'block_duration': 201,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.58-0.58',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 69,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 201,
#    u'stim_duration': 201,
#    u'time_elapsed': 987840,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 985,
#    u'trial_num': 58,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 58,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 986,
#   u'dateTime': 1460135761449,
#   u'trialdata': {u'block_duration': 176,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.59-0.59',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 68,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 176,
#    u'stim_duration': 176,
#    u'time_elapsed': 988088,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 986,
#    u'trial_num': 59,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 59,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 987,
#   u'dateTime': 1460135762623,
#   u'trialdata': {u'block_duration': 1114,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.60-0.60',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 67,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 1114,
#    u'stim_duration': 1114,
#    u'time_elapsed': 989262,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 987,
#    u'trial_num': 60,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 60,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 988,
#   u'dateTime': 1460135763142,
#   u'trialdata': {u'block_duration': 438,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.61-0.61',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 66,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 438,
#    u'stim_duration': 438,
#    u'time_elapsed': 989781,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 988,
#    u'trial_num': 61,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 61,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 989,
#   u'dateTime': 1460135764174,
#   u'trialdata': {u'block_duration': 973,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.62-0.62',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 65,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 973,
#    u'stim_duration': 973,
#    u'time_elapsed': 990813,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 989,
#    u'trial_num': 62,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 62,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 990,
#   u'dateTime': 1460135766273,
#   u'trialdata': {u'block_duration': 2029,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-67.63-0.63',
#    u'mouse_click': u'Collect',
#    u'red_fish_num': 64,
#    u'release': u'Keep',
#    u'round_num': 0,
#    u'rt': 2029,
#    u'stim_duration': 2029,
#    u'time_elapsed': 992912,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 0,
#    u'trial_id': u'stim',
#    u'trial_index': 990,
#    u'trial_num': 63,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 63,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 991,
#   u'dateTime': 1460135768070,
#   u'trialdata': {u'internal_node_id': u'0.0-68.0',
#    u'key_press': 13,
#    u'rt': 1734,
#    u'time_elapsed': 994709,
#    u'trial_id': u'round_over',
#    u'trial_index': 991,
#    u'trial_type': u'poldrack-text'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 992,
#   u'dateTime': 1460135769683,
#   u'trialdata': {u'block_duration': 1503,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-69.0-0.0',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 127,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 1503,
#    u'stim_duration': 1503,
#    u'time_elapsed': 996322,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 63,
#    u'trial_id': u'stim',
#    u'trial_index': 992,
#    u'trial_num': 0,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 0,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 993,
#   u'dateTime': 1460135770073,
#   u'trialdata': {u'block_duration': 299,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-69.1-0.1',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 126,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 299,
#    u'stim_duration': 299,
#    u'time_elapsed': 996712,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 63,
#    u'trial_id': u'stim',
#    u'trial_index': 993,
#    u'trial_num': 1,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 1,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 994,
#   u'dateTime': 1460135770713,
#   u'trialdata': {u'block_duration': 539,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-69.2-0.2',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 125,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 539,
#    u'stim_duration': 539,
#    u'time_elapsed': 997352,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 63,
#    u'trial_id': u'stim',
#    u'trial_index': 994,
#    u'trial_num': 2,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 2,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 995,
#   u'dateTime': 1460135771192,
#   u'trialdata': {u'block_duration': 371,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-69.3-0.3',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 124,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 371,
#    u'stim_duration': 371,
#    u'time_elapsed': 997831,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 63,
#    u'trial_id': u'stim',
#    u'trial_index': 995,
#    u'trial_num': 3,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 3,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 996,
#   u'dateTime': 1460135771708,
#   u'trialdata': {u'block_duration': 431,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-69.4-0.4',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 123,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 431,
#    u'stim_duration': 431,
#    u'time_elapsed': 998347,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 63,
#    u'trial_id': u'stim',
#    u'trial_index': 996,
#    u'trial_num': 4,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 4,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 997,
#   u'dateTime': 1460135772166,
#   u'trialdata': {u'block_duration': 366,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-69.5-0.5',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 122,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 366,
#    u'stim_duration': 366,
#    u'time_elapsed': 998805,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 63,
#    u'trial_id': u'stim',
#    u'trial_index': 997,
#    u'trial_num': 5,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 5,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 998,
#   u'dateTime': 1460135772624,
#   u'trialdata': {u'block_duration': 373,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-69.6-0.6',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 121,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 373,
#    u'stim_duration': 373,
#    u'time_elapsed': 999263,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 63,
#    u'trial_id': u'stim',
#    u'trial_index': 998,
#    u'trial_num': 6,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 6,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  {u'current_trial': 999,
#   u'dateTime': 1460135773111,
#   u'trialdata': {u'block_duration': 409,
#    u'exp_stage': u'test',
#    u'internal_node_id': u'0.0-69.7-0.7',
#    u'mouse_click': u'goFish',
#    u'red_fish_num': 120,
#    u'release': u'Keep',
#    u'round_num': 1,
#    u'rt': 409,
#    u'stim_duration': 409,
#    u'time_elapsed': 999750,
#    u'timing_post_trial': 0,
#    u'tournament_bank': 63,
#    u'trial_id': u'stim',
#    u'trial_index': 999,
#    u'trial_num': 7,
#    u'trial_type': u'single-stim-button',
#    u'trip_bank': 7,
#    u'weather': u'Sunny'},
#   u'uniqueid': u'583'},
#  ...]

# %% [markdown]
# We see that the data is quite large. After all, this cell holds all of the data for that task! The exact format of this data can differ depending on the _template_ used in expfactory. There are two main templates for us right now - jspsych and expfactory-survey.
#
# Rather than explain how this data is stored, there are expanalysis commands to help you extract it. But before we get there let's finish loading the data!
#
# Right now we have loaded _all_ of the data from expfactory, regardless of whether we want it or not. To filter it down to only the stuff we want, we have to make use of another function:

# %%
from expanalysis.experiments.utils import result_filter

#This filter ensures that all datasets come after this time
first_update_time = '2016-04-17T04:24:37.041870Z'
data = result_filter(source_data, battery = ['Self Regulation Pilot', 'Self Regulation Subset Battery'], \
                     finishtime = first_update_time)

# %% [markdown]
# `result_filter` can filter the data based on battery names, particular workers, particular experiments, or time. It can either take a string or array as the argument for each field and filter appropriately. (Though documentation is a work in progress, if I've been good you can see the way to use any function by typing `function?`
#
# Now that we've filtered it, we are going to use a few more helper functions that add 'nice to have' features to the data.

# %%
from expanalysis.experiments.utils import anonymize_data
from expanalysis.experiments.jspsych import calc_time_taken, get_post_task_responses
worker_lookup = anonymize_data(data)
calc_time_taken(data)
get_post_task_responses(data)

# %% [markdown]
# These functions (in order)
# - replace the worker_IDs with anonymized subject IDs and stores that relationship in a worker_lookup dictionary
# - Adds columns to the data set for the total time taken for each task (when it is available, i.e. jspsych experiments), time on instructions and time on task
# - Adds a column with the post task questionnaire responses
#
# Below I've printed the columns (compare to the columns when we first uploaded the data) and used another helper function to print the time taken

# %%
print data.columns, '\n'

def print_time(data, time_col = 'ontask_time'):
    '''Prints time taken for each experiment in minutes
    :param time_col: Dataframe column of time in seconds
    '''
    df = data.copy()    
    assert time_col in df, \
        '"%s" has not been calculated yet. Use calc_time_taken method' % (time_col)
    #drop rows where time can't be calculated
    df = df.dropna(subset = [time_col])
    time = (df.groupby('experiment_exp_id')[time_col].mean()/60.0).round(2)
    print(time)
    return time


time_taken = print_time(data)
# Out:
# Index([         u'finishtime',        u'battery_name',           u'worker_id',
#                   u'platform', u'experiment_template',   u'experiment_exp_id',
#                       u'data',             u'browser',          u'total_time',
#              u'instruct_time',         u'ontask_time', u'post_task_responses'],
#       dtype='object')
#
# experiment_exp_id
# adaptive_n_back                                15.85
# angling_risk_task_always_sunny                 11.10
# attention_network_task                         14.82
# bickel_titrator                                 4.84
# choice_reaction_time                            3.75
# columbia_card_task_cold                         6.07
# columbia_card_task_hot                          4.74
# dietary_decision                                5.65
# digit_span                                      8.69
# directed_forgetting                            19.86
# discount_titrate                                2.70
# dot_pattern_expectancy                         17.74
# go_nogo                                         7.93
# hierarchical_rule                              27.92
# information_sampling_task                       7.59
# keep_track                                     10.61
# kirby                                           2.11
# local_global_letter                             5.56
# motor_selective_stop_signal                    19.36
# probabilistic_selection                        17.09
# psychological_refractory_period_two_choices    12.72
# ravens                                         13.04
# recent_probes                                  19.44
# shift_task                                     20.42
# simon                                           7.19
# simple_reaction_time                            4.32
# spatial_span                                    7.64
# stim_selective_stop_signal                     18.34
# stop_signal                                    29.27
# stroop                                          8.02
# threebytwo                                     24.96
# tower_of_london                                 5.40
# two_stage_decision                             18.63
# willingness_to_wait                             9.55
# writing_task                                   22.55
# Name: ontask_time, dtype: float64

# %% [markdown]
# Done loading the data!
#
# ## Accessing experiments
#
# Above I mentioned that the data is stored in different ways depending on the experiment, and is in a relatively uuseable form (in one cell of a dataframe). Expanalysis has functions that let us extract experiments from either rows of the total dataframe (so returning one subject's data) or based on an experiment ID (returning a dataframe with all the data across ubjects for one experiment
#
# Below are examples. Many expanalysis functions take a `clean` flag. If the `clean` flag is set to True (by default) then the data is transformed in many ways (which differ based on the experiment) before being returned. If you'd like to see the raw data (but still have the data returned as a pretty pandas dataframe), set `clean` to false.

# %%
from expanalysis.experiments.processing import extract_row,  extract_experiment

one_subject_df = extract_row(data.iloc[1])
# To extract one experiment, you need to provide the exact experiment ID. If you want to see what experiment IDs
# are in the dataframe, you can type 'data['experiment_exp_id'].unique() as below'
one_experiment_df = extract_experiment(data, 'stroop')

#viewing the experiments in the dataframe
print data.experiment_exp_id.unique(), '\n'

print 'Data for one subject for the %s' % data.iloc[1].experiment_exp_id, 'Dimensions: ', one_subject_df.shape
print 'Data for all subjects on the stroop task. Dimensions: ', one_experiment_df.shape
# Out:
# [u'adaptive_n_back' u'angling_risk_task_always_sunny'
#  u'attention_network_task' u'bickel_titrator' u'bis11_survey'
#  u'bis_bas_survey' u'brief_self_control_survey' u'choice_reaction_time'
#  u'cognitive_reflection_survey' u'columbia_card_task_cold'
#  u'columbia_card_task_hot' u'demographics_survey' u'dickman_survey'
#  u'dietary_decision' u'digit_span' u'directed_forgetting'
#  u'discount_titrate' u'dospert_eb_survey' u'dospert_rp_survey'
#  u'dospert_rt_survey' u'dot_pattern_expectancy' u'eating_survey'
#  u'erq_survey' u'five_facet_mindfulness_survey'
#  u'future_time_perspective_survey' u'go_nogo' u'grit_scale_survey'
#  u'hierarchical_rule' u'holt_laury_survey' u'impulsive_venture_survey'
#  u'information_sampling_task' u'keep_track' u'kirby'
#  u'leisure_time_activity_survey' u'local_global_letter'
#  u'mindful_attention_awareness_survey' u'motor_selective_stop_signal'
#  u'mpq_control_survey' u'probabilistic_selection'
#  u'psychological_refractory_period_two_choices' u'ravens' u'recent_probes'
#  u'selection_optimization_compensation' u'self_regulation_survey'
#  u'sensation_seeking_survey' u'shift_task' u'simon' u'simple_reaction_time'
#  u'spatial_span' u'stim_selective_stop_signal' u'stop_signal' u'stroop'
#  u'ten_item_personality_survey' u'theories_of_willpower_survey'
#  u'threebytwo' u'time_perspective_survey' u'tower_of_london'
#  u'two_stage_decision' u'upps_impulsivity_survey' u'willingness_to_wait'
#  u'writing_task']
#
# Data for one subject for the adaptive_n_back Dimensions:  (445, 20)
# Data for all subjects on the stroop task. Dimensions:  (5160, 18)

# %% [markdown]
# We can look at the data for these subjects. I'll just use `the one_experiment_df` as an example. If your screen is wide enough, pandas prints very nicely. Otherwise it can be a bit messy looking. As usual, I'll print the columns first. Below I also print the columns for the stroop task _before_ it is "cleaned" so you can get a small sense of what is changing.

# %%
print 'Columns:', one_experiment_df.columns , '\n'
print 'Columns before cleaning:', extract_experiment(data,'stroop', clean = False).columns, '\n'
print one_experiment_df
# Out:
# Columns: Index([      u'battery_name',          u'condition',            u'correct',
#          u'correct_response',          u'exp_stage',  u'experiment_exp_id',
#                u'finishtime',       u'focus_shifts',        u'full_screen',
#                 u'key_press', u'possible_responses',                 u'rt',
#                u'stim_color',          u'stim_word',       u'time_elapsed',
#                  u'trial_id',         u'trial_type',          u'worker_id'],
#       dtype='object')
#
# Columns before cleaning: Index([      u'battery_name',     u'block_duration',          u'condition',
#                   u'correct',   u'correct_response',         u'credit_var',
#                    u'exp_id',          u'exp_stage',  u'experiment_exp_id',
#         u'feedback_duration',         u'finishtime',       u'focus_shifts',
#               u'full_screen',   u'internal_node_id',          u'key_press',
#        u'possible_responses',          u'responses',                 u'rt',
#                u'stim_color',      u'stim_duration',          u'stim_word',
#                  u'stimulus',       u'time_elapsed',  u'timing_post_trial',
#                  u'trial_id',        u'trial_index',         u'trial_type',
#              u'view_history',          u'worker_id'],
#       dtype='object')
#
#                         battery_name    condition correct  correct_response  \
# stroop_0_4     Self Regulation Pilot  incongruent   False              66.0
# stroop_0_6     Self Regulation Pilot    congruent    True              66.0
# stroop_0_8     Self Regulation Pilot  incongruent    True              82.0
# stroop_0_10    Self Regulation Pilot    congruent    True              82.0
# stroop_0_12    Self Regulation Pilot  incongruent    True              71.0
# stroop_0_14    Self Regulation Pilot    congruent    True              71.0
# stroop_0_16    Self Regulation Pilot  incongruent    True              66.0
# stroop_0_18    Self Regulation Pilot  incongruent    True              71.0
# stroop_0_20    Self Regulation Pilot  incongruent    True              66.0
# stroop_0_22    Self Regulation Pilot    congruent    True              82.0
# stroop_0_24    Self Regulation Pilot  incongruent    True              66.0
# stroop_0_26    Self Regulation Pilot    congruent    True              82.0
# stroop_0_28    Self Regulation Pilot    congruent    True              66.0
# stroop_0_30    Self Regulation Pilot    congruent    True              71.0
# stroop_0_32    Self Regulation Pilot    congruent    True              71.0
# stroop_0_34    Self Regulation Pilot  incongruent    True              82.0
# stroop_0_36    Self Regulation Pilot    congruent    True              71.0
# stroop_0_38    Self Regulation Pilot  incongruent    True              82.0
# stroop_0_40    Self Regulation Pilot  incongruent    True              71.0
# stroop_0_42    Self Regulation Pilot  incongruent    True              82.0
# stroop_0_44    Self Regulation Pilot    congruent    True              66.0
# stroop_0_46    Self Regulation Pilot  incongruent    True              71.0
# stroop_0_48    Self Regulation Pilot    congruent    True              66.0
# stroop_0_50    Self Regulation Pilot    congruent    True              82.0
# stroop_0_53    Self Regulation Pilot  incongruent    True              82.0
# stroop_0_55    Self Regulation Pilot  incongruent    True              82.0
# stroop_0_57    Self Regulation Pilot  incongruent    True              82.0
# stroop_0_59    Self Regulation Pilot  incongruent    True              82.0
# stroop_0_61    Self Regulation Pilot    congruent    True              66.0
# stroop_0_63    Self Regulation Pilot    congruent    True              82.0
# ...                              ...          ...     ...               ...
# stroop_42_185  Self Regulation Pilot    congruent    True              82.0
# stroop_42_187  Self Regulation Pilot  incongruent    True              71.0
# stroop_42_189  Self Regulation Pilot    congruent    True              66.0
# stroop_42_191  Self Regulation Pilot  incongruent    True              66.0
# stroop_42_193  Self Regulation Pilot    congruent    True              71.0
# stroop_42_195  Self Regulation Pilot    congruent    True              71.0
# stroop_42_197  Self Regulation Pilot  incongruent    True              66.0
# stroop_42_199  Self Regulation Pilot    congruent    True              66.0
# stroop_42_201  Self Regulation Pilot  incongruent    True              82.0
# stroop_42_203  Self Regulation Pilot  incongruent    True              66.0
# stroop_42_205  Self Regulation Pilot  incongruent    True              66.0
# stroop_42_207  Self Regulation Pilot  incongruent    True              82.0
# stroop_42_209  Self Regulation Pilot  incongruent    True              82.0
# stroop_42_211  Self Regulation Pilot    congruent    True              66.0
# stroop_42_213  Self Regulation Pilot    congruent    True              71.0
# stroop_42_215  Self Regulation Pilot    congruent    True              82.0
# stroop_42_217  Self Regulation Pilot    congruent    True              66.0
# stroop_42_219  Self Regulation Pilot    congruent    True              82.0
# stroop_42_221  Self Regulation Pilot  incongruent    True              82.0
# stroop_42_223  Self Regulation Pilot    congruent    True              82.0
# stroop_42_225  Self Regulation Pilot    congruent    True              82.0
# stroop_42_227  Self Regulation Pilot    congruent    True              66.0
# stroop_42_229  Self Regulation Pilot  incongruent    True              66.0
# stroop_42_231  Self Regulation Pilot  incongruent    True              82.0
# stroop_42_233  Self Regulation Pilot    congruent    True              71.0
# stroop_42_235  Self Regulation Pilot    congruent    True              82.0
# stroop_42_237  Self Regulation Pilot    congruent    True              66.0
# stroop_42_239  Self Regulation Pilot    congruent    True              82.0
# stroop_42_241  Self Regulation Pilot  incongruent    True              66.0
# stroop_42_243  Self Regulation Pilot  incongruent    True              66.0
#
#               exp_stage experiment_exp_id                   finishtime  \
# stroop_0_4          NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_6          NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_8          NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_10         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_12         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_14         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_16         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_18         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_20         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_22         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_24         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_26         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_28         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_30         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_32         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_34         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_36         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_38         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_40         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_42         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_44         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_46         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_48         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_50         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_53         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_55         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_57         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_59         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_61         NaN            stroop  2016-04-12T19:19:42.618322Z
# stroop_0_63         NaN            stroop  2016-04-12T19:19:42.618322Z
# ...                 ...               ...                          ...
# stroop_42_185      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_187      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_189      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_191      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_193      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_195      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_197      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_199      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_201      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_203      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_205      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_207      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_209      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_211      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_213      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_215      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_217      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_219      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_221      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_223      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_225      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_227      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_229      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_231      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_233      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_235      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_237      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_239      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_241      test            stroop  2016-05-21T02:50:23.630904Z
# stroop_42_243      test            stroop  2016-05-21T02:50:23.630904Z
#
#                focus_shifts full_screen  key_press possible_responses    rt  \
# stroop_0_4              NaN         NaN       -1.0       [66, 71, 82]    -1
# stroop_0_6              NaN         NaN       66.0       [66, 71, 82]   590
# stroop_0_8              NaN         NaN       82.0       [66, 71, 82]  1073
# stroop_0_10             NaN         NaN       82.0       [66, 71, 82]  1154
# stroop_0_12             NaN         NaN       71.0       [66, 71, 82]  1397
# stroop_0_14             NaN         NaN       71.0       [66, 71, 82]  1123
# stroop_0_16             NaN         NaN       66.0       [66, 71, 82]  1042
# stroop_0_18             NaN         NaN       71.0       [66, 71, 82]  1132
# stroop_0_20             NaN         NaN       66.0       [66, 71, 82]  1080
# stroop_0_22             NaN         NaN       82.0       [66, 71, 82]   983
# stroop_0_24             NaN         NaN       66.0       [66, 71, 82]  1146
# stroop_0_26             NaN         NaN       82.0       [66, 71, 82]  1138
# stroop_0_28             NaN         NaN       66.0       [66, 71, 82]   813
# stroop_0_30             NaN         NaN       71.0       [66, 71, 82]   977
# stroop_0_32             NaN         NaN       71.0       [66, 71, 82]   739
# stroop_0_34             NaN         NaN       82.0       [66, 71, 82]   904
# stroop_0_36             NaN         NaN       71.0       [66, 71, 82]   853
# stroop_0_38             NaN         NaN       82.0       [66, 71, 82]   921
# stroop_0_40             NaN         NaN       71.0       [66, 71, 82]  1113
# stroop_0_42             NaN         NaN       82.0       [66, 71, 82]   940
# stroop_0_44             NaN         NaN       66.0       [66, 71, 82]   870
# stroop_0_46             NaN         NaN       71.0       [66, 71, 82]   996
# stroop_0_48             NaN         NaN       66.0       [66, 71, 82]   770
# stroop_0_50             NaN         NaN       82.0       [66, 71, 82]   694
# stroop_0_53             NaN         NaN       82.0       [66, 71, 82]   835
# stroop_0_55             NaN         NaN       82.0       [66, 71, 82]  1434
# stroop_0_57             NaN         NaN       82.0       [66, 71, 82]  1027
# stroop_0_59             NaN         NaN       82.0       [66, 71, 82]   853
# stroop_0_61             NaN         NaN       66.0       [66, 71, 82]   934
# stroop_0_63             NaN         NaN       82.0       [66, 71, 82]   750
# ...                     ...         ...        ...                ...   ...
# stroop_42_185           0.0        True       82.0       [66, 71, 82]   425
# stroop_42_187           0.0        True       71.0       [66, 71, 82]  1183
# stroop_42_189           0.0        True       66.0       [66, 71, 82]   693
# stroop_42_191           0.0        True       66.0       [66, 71, 82]   452
# stroop_42_193           0.0        True       71.0       [66, 71, 82]   545
# stroop_42_195           0.0        True       71.0       [66, 71, 82]   451
# stroop_42_197           0.0        True       66.0       [66, 71, 82]   554
# stroop_42_199           0.0        True       66.0       [66, 71, 82]   423
# stroop_42_201           0.0        True       82.0       [66, 71, 82]   435
# stroop_42_203           0.0        True       66.0       [66, 71, 82]   955
# stroop_42_205           0.0        True       66.0       [66, 71, 82]   444
# stroop_42_207           0.0        True       82.0       [66, 71, 82]   642
# stroop_42_209           0.0        True       82.0       [66, 71, 82]   413
# stroop_42_211           0.0        True       66.0       [66, 71, 82]   612
# stroop_42_213           0.0        True       71.0       [66, 71, 82]   643
# stroop_42_215           0.0        True       82.0       [66, 71, 82]   490
# stroop_42_217           0.0        True       66.0       [66, 71, 82]   526
# stroop_42_219           0.0        True       82.0       [66, 71, 82]   485
# stroop_42_221           0.0        True       82.0       [66, 71, 82]   662
# stroop_42_223           0.0        True       82.0       [66, 71, 82]   439
# stroop_42_225           0.0        True       82.0       [66, 71, 82]   374
# stroop_42_227           0.0        True       66.0       [66, 71, 82]  1193
# stroop_42_229           0.0        True       66.0       [66, 71, 82]   359
# stroop_42_231           0.0        True       82.0       [66, 71, 82]   591
# stroop_42_233           0.0        True       71.0       [66, 71, 82]   863
# stroop_42_235           0.0        True       82.0       [66, 71, 82]   589
# stroop_42_237           0.0        True       66.0       [66, 71, 82]   493
# stroop_42_239           0.0        True       82.0       [66, 71, 82]   638
# stroop_42_241           0.0        True       66.0       [66, 71, 82]   684
# stroop_42_243           0.0        True       66.0       [66, 71, 82]   696
#
#               stim_color stim_word  time_elapsed trial_id  \
# stroop_0_4          blue     green         52830     stim
# stroop_0_6          blue      blue         56123     stim
# stroop_0_8           red     green         59406     stim
# stroop_0_10          red       red         62690     stim
# stroop_0_12        green      blue         65976     stim
# stroop_0_14        green     green         69253     stim
# stroop_0_16         blue     green         72540     stim
# stroop_0_18        green       red         75833     stim
# stroop_0_20         blue       red         79129     stim
# stroop_0_22          red       red         82410     stim
# stroop_0_24         blue       red         85700     stim
# stroop_0_26          red       red         88993     stim
# stroop_0_28         blue      blue         92290     stim
# stroop_0_30        green     green         95576     stim
# stroop_0_32        green     green         98866     stim
# stroop_0_34          red     green        102162     stim
# stroop_0_36        green     green        105433     stim
# stroop_0_38          red      blue        108713     stim
# stroop_0_40        green       red        112000     stim
# stroop_0_42          red      blue        115279     stim
# stroop_0_44         blue      blue        118573     stim
# stroop_0_46        green      blue        121859     stim
# stroop_0_48         blue      blue        125146     stim
# stroop_0_50          red       red        128432     stim
# stroop_0_53          red      blue        137159     stim
# stroop_0_55          red     green        140449     stim
# stroop_0_57          red     green        143739     stim
# stroop_0_59          red     green        147016     stim
# stroop_0_61         blue      blue        150296     stim
# stroop_0_63          red       red        153589     stim
# ...                  ...       ...           ...      ...
# stroop_42_185        red       red        342650     stim
# stroop_42_187      green      blue        345908     stim
# stroop_42_189       blue      blue        349166     stim
# stroop_42_191       blue       red        352423     stim
# stroop_42_193      green     green        355681     stim
# stroop_42_195      green     green        358935     stim
# stroop_42_197       blue     green        362200     stim
# stroop_42_199       blue      blue        365463     stim
# stroop_42_201        red      blue        368720     stim
# stroop_42_203       blue     green        371975     stim
# stroop_42_205       blue       red        375230     stim
# stroop_42_207        red      blue        378493     stim
# stroop_42_209        red      blue        381751     stim
# stroop_42_211       blue      blue        385007     stim
# stroop_42_213      green     green        388263     stim
# stroop_42_215        red       red        391523     stim
# stroop_42_217       blue      blue        394780     stim
# stroop_42_219        red       red        398038     stim
# stroop_42_221        red      blue        401309     stim
# stroop_42_223        red       red        404564     stim
# stroop_42_225        red       red        407822     stim
# stroop_42_227       blue      blue        411082     stim
# stroop_42_229       blue     green        414339     stim
# stroop_42_231        red     green        417596     stim
# stroop_42_233      green     green        420859     stim
# stroop_42_235        red       red        424117     stim
# stroop_42_237       blue      blue        427383     stim
# stroop_42_239        red       red        430637     stim
# stroop_42_241       blue       red        433900     stim
# stroop_42_243       blue       red        437155     stim
#
#                         trial_type worker_id
# stroop_0_4     poldrack-categorize      s000
# stroop_0_6     poldrack-categorize      s000
# stroop_0_8     poldrack-categorize      s000
# stroop_0_10    poldrack-categorize      s000
# stroop_0_12    poldrack-categorize      s000
# stroop_0_14    poldrack-categorize      s000
# stroop_0_16    poldrack-categorize      s000
# stroop_0_18    poldrack-categorize      s000
# stroop_0_20    poldrack-categorize      s000
# stroop_0_22    poldrack-categorize      s000
# stroop_0_24    poldrack-categorize      s000
# stroop_0_26    poldrack-categorize      s000
# stroop_0_28    poldrack-categorize      s000
# stroop_0_30    poldrack-categorize      s000
# stroop_0_32    poldrack-categorize      s000
# stroop_0_34    poldrack-categorize      s000
# stroop_0_36    poldrack-categorize      s000
# stroop_0_38    poldrack-categorize      s000
# stroop_0_40    poldrack-categorize      s000
# stroop_0_42    poldrack-categorize      s000
# stroop_0_44    poldrack-categorize      s000
# stroop_0_46    poldrack-categorize      s000
# stroop_0_48    poldrack-categorize      s000
# stroop_0_50    poldrack-categorize      s000
# stroop_0_53    poldrack-categorize      s000
# stroop_0_55    poldrack-categorize      s000
# stroop_0_57    poldrack-categorize      s000
# stroop_0_59    poldrack-categorize      s000
# stroop_0_61    poldrack-categorize      s000
# stroop_0_63    poldrack-categorize      s000
# ...                            ...       ...
# stroop_42_185  poldrack-categorize      s044
# stroop_42_187  poldrack-categorize      s044
# stroop_42_189  poldrack-categorize      s044
# stroop_42_191  poldrack-categorize      s044
# stroop_42_193  poldrack-categorize      s044
# stroop_42_195  poldrack-categorize      s044
# stroop_42_197  poldrack-categorize      s044
# stroop_42_199  poldrack-categorize      s044
# stroop_42_201  poldrack-categorize      s044
# stroop_42_203  poldrack-categorize      s044
# stroop_42_205  poldrack-categorize      s044
# stroop_42_207  poldrack-categorize      s044
# stroop_42_209  poldrack-categorize      s044
# stroop_42_211  poldrack-categorize      s044
# stroop_42_213  poldrack-categorize      s044
# stroop_42_215  poldrack-categorize      s044
# stroop_42_217  poldrack-categorize      s044
# stroop_42_219  poldrack-categorize      s044
# stroop_42_221  poldrack-categorize      s044
# stroop_42_223  poldrack-categorize      s044
# stroop_42_225  poldrack-categorize      s044
# stroop_42_227  poldrack-categorize      s044
# stroop_42_229  poldrack-categorize      s044
# stroop_42_231  poldrack-categorize      s044
# stroop_42_233  poldrack-categorize      s044
# stroop_42_235  poldrack-categorize      s044
# stroop_42_237  poldrack-categorize      s044
# stroop_42_239  poldrack-categorize      s044
# stroop_42_241  poldrack-categorize      s044
# stroop_42_243  poldrack-categorize      s044
#
# [5160 rows x 18 columns]

# %% [markdown]
# Notice above that the _index_ of the dataframe (the left most column, which isn't really a column, but an index) has a particular structure. It is: 'exp ID' _ 'subject number relative to that experiment' _ 'trial'. Above you can see that there seem to be missing trials. That's because these 'trials' can sometimes just be one jspsych write. So for the stroop task a fixation is displayed (which we don't care about) and then a stim is displayed (where all the information we care about is gathered). The "cleaning" removes the rows we don't care about, making it look neater. Also note that the subject number here is **not** related to the worker_id (or the now anonymized subject ids). It is just an index of the different datasets. If we have 44 workers with the stroop task, the index will go from 0 to 43.
#
# There's too much pandas specific syntax to go through (look that up yourself), but what we have here is just a dataframe. I'll do some basic manipulations below so you can get a sense for what you can do.

# %%
# groups the dataframe by the condition columns (which has two levels), and gets the median rt for each level
contrast1 = one_experiment_df.groupby('condition')['rt'].median(), '\n'

# same as above, but now splits up by worker
contrast2 = one_experiment_df.groupby(['worker_id','condition'])['rt'].median()

# you can get multiple variables
contrast3 = one_experiment_df.groupby('condition')[['rt','correct']].agg(['mean','median'])

# you can also just subset to something you care about. Below I used string substitution
worker_df = one_experiment_df.query('worker_id ==  "%s"' )  % 's001' 
# same thing, different way
worker_df2 = one_experiment_df[one_experiment_df['worker_id'] == 's001']

# %%
#replace variable below to look at the different outputs
print contrast1
# Out:
# (condition
# congruent      634
# incongruent    752
# Name: rt, dtype: int64, '\n')

# %% [markdown]
# When you want to get a CSV file, you can use basic pandas syntax:

# %%
path_to_save_location = '~/'
one_experiment_df.to_csv(path_to_save_location + 'stroop.csv')

# %% [markdown]
# ## Automated post processing
#
# Every time you run `extract_experiment` it has to clean the data all over again. That cleaning can sometimes be costly. Though I am working on efficiency, occasionally this can take up to 1s for a single subject! I don't want to wait that long over and over! To deal with this there is another function that will post process your data and save it in the data matrix. For example, after we run this command, the data cell for row 2 will have the post processed data rather than the raw data.
#
# _After this step the raw data is gone from this data set_. This is why I have separated out `source_data` from `data` above. `source_data` will maintain the raw data. Of course we could always load the data again, but I often am playing with the data in an active ipythong notebook, and this makes it easier.
#
# Post processing is done using the command below. It can take a while, but it only has to run once! It will print out progress along the way. Some experiments have manipulation checks or other things that may print out - totally experiment dependent.
#
# You could save the data at this stage so that you don't have to go through all of these steps each time. I haven't done that yet, but probably will create a helper function to do so in the future.

# %%
from expanalysis.experiments.processing import post_process_data

post_process_data(data)

# %% [markdown]
# ## Dependent Variables calculation
#
# Dependent variables can be extracted for one experiment, or for many experiments (as seen below). `extract_DVs` both appends columns to the data dataframe that hold each subject/task dependent variable, as well as extract those dependent variables to a new dataframe that is subjects x dependent variables. This is the primary dataframe of interest (we will use it to create covariance matrixes).
#
# These functions all rely on experiment specific functions defined in expanalysis.experiments.jspsych_processing which are all named 'calc_experiment ID_DV'. Though I haven't made one yet, there will be a separate file for surveys. The dependent variables currently calculated are somewhat haphazard. I do not expect all of them will actually be useful. For example, I calculated the number of missing responses for many tasks. I do not think that is a DV of scientific interest.

# %%
from expanalysis.experiments.processing import get_DV, extract_DVs
one_experiment_DV = get_DV(data,'stroop')
DV_df = extract_DVs(data)
# Out:
# adaptive_n_back : 2.66923189163
# angling_risk_task_always_sunny : 7.21298599243
# attention_network_task : 3.16573095322
# bickel_titrator : 0.00623393058777
# bis11_survey : 0.00827193260193
# bis_bas_survey : 0.00872921943665
# brief_self_control_survey : 0.00438189506531
# choice_reaction_time : 1.9067530632
# cognitive_reflection_survey : 0.754488945007
# columbia_card_task_cold : 2.58764386177
# DV calculated failed for worker: s008
# DV calculated failed for worker: s030
# columbia_card_task_hot : 2.98071098328
# demographics_survey : 0.00792098045349
# dickman_survey : 0.00814199447632
# dietary_decision : 0.00728702545166
# digit_span : 1.59749913216
# directed_forgetting : 0.00633692741394
# discount_titrate : 0.00797915458679
# dospert_eb_survey : 0.0063738822937
# dospert_rp_survey : 0.00571608543396
# dospert_rt_survey : 0.00422286987305
# dot_pattern_expectancy : 2.21447896957
# eating_survey : 0.00528407096863
# erq_survey : 0.00802302360535
# five_facet_mindfulness_survey : 0.00877785682678
# future_time_perspective_survey : 0.00630903244019
# go_nogo : 5.09373307228
# grit_scale_survey : 0.00715398788452
# hierarchical_rule : 2.93811416626
# holt_laury_survey : 0.00528407096863
# impulsive_venture_survey : 0.00829100608826
# information_sampling_task : 2.50693702698
# DV calculated failed for worker: s000
# DV calculated failed for worker: s062
# keep_track : 1.53371596336
# kirby : 0.00767302513123
# leisure_time_activity_survey : 0.0074291229248
# local_global_letter : 2.60676789284
# mindful_attention_awareness_survey : 0.00974798202515
# motor_selective_stop_signal : 0.00897002220154
# mpq_control_survey : 0.00565004348755
# probabilistic_selection : 6.4057199955
# psychological_refractory_period_two_choices : 0.00491213798523
# ravens : 1.0433049202
# recent_probes : 0.00497102737427
# selection_optimization_compensation : 0.00515699386597
# self_regulation_survey : 0.00721597671509
# sensation_seeking_survey : 0.0093719959259
# shift_task : 0.00859212875366
# simon : 2.19002604485
# simple_reaction_time : 1.40239500999
# spatial_span : 1.53079986572
# stim_selective_stop_signal : 0.00544595718384
# stop_signal : 7.26022815704
# stroop : 2.07674980164
# ten_item_personality_survey : 0.00500798225403
# theories_of_willpower_survey : 0.00546908378601
# threebytwo : 4.85527992249
# time_perspective_survey : 0.0051851272583
# tower_of_london : 2.17879009247
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-72a1f886a28c> in <module>()
#       1 from expanalysis.experiments.processing import get_DV, extract_DVs
#       2 one_experiment_DV = get_DV(data,'stroop')
# ----> 3 DV_df = extract_DVs(data)
#
# /media/Data/Ian/Experiments/expfactory/expfactory-analysis/expanalysis/experiments/processing.pyc in extract_DVs(data, use_check)
#     331     """
#     332     if not 'DV_val' in data.columns:
# --> 333         calc_DVs(data, use_check)
#     334     data = data[data['DV_val'].isnull()==False]
#     335     DV_list = []
#
# /media/Data/Ian/Experiments/expfactory/expfactory-analysis/expanalysis/experiments/processing.pyc in calc_DVs(data, use_check)
#     314         tic = time.time()
#     315         subset = data[data['experiment_exp_id'] == exp_id]
# --> 316         dvs, description = get_DV(subset,exp_id, use_check)
#     317         subset = subset.query('worker_id in %s' % dvs.keys())
#     318         if len(dvs) == len(subset):
#
# /media/Data/Ian/Experiments/expfactory/expfactory-analysis/expanalysis/experiments/processing.pyc in get_DV(data, exp_id, use_check)
#     296     if fun:
#     297         df = extract_experiment(data,exp_id)
# --> 298         return fun(df, use_check)
#     299     else:
#     300         return {},''
#
# /media/Data/Ian/Experiments/expfactory/expfactory-analysis/expanalysis/experiments/jspsych_processing.pyc in multi_worker_wrap(group_df, use_check)
#      33             return group_dvs, ''
#      34         if 'passed_check' in group_df.columns and use_check:
# ---> 35             group_df = group_df[group_df['passed_check']]
#      36         for worker in pandas.unique(group_df['worker_id']):
#      37             df = group_df.query('worker_id == "%s"' %worker)
#
# /home/ian/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1984         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1985             # either boolean or fancy integer index
# -> 1986             return self._getitem_array(key)
#    1987         elif isinstance(key, DataFrame):
#    1988             return self._getitem_frame(key)
#
# /home/ian/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2011     def _getitem_array(self, key):
#    2012         # also raises Exception if object array with NA values
# -> 2013         if com.is_bool_indexer(key):
#    2014             # warning here just in case -- previously __setitem__ was
#    2015             # reindexing but __getitem__ was not; it seems more reasonable to
#
# /home/ian/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in is_bool_indexer(key)
#    1848             if not lib.is_bool_array(key):
#    1849                 if isnull(key).any():
# -> 1850                     raise ValueError('cannot index with vector containing '
#    1851                                      'NA / NaN values')
#    1852                 return False
#
# ValueError: cannot index with vector containing NA / NaN values
